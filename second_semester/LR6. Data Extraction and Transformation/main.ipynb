# %% [markdown]
# # Data extraction and transformation

# %% [markdown]
# Установим все необходимые библиотеки

# %%
# %pip install -r requirements.txt
# Out:
# Requirement already satisfied: contourpy==1.3.3 in c:\Users\Aleksandr Riabkov\Desktop\Itmo.py\ITMO.py\second_semester\LR5. Scikit-learn. Regression\venv\Lib\site-packages (from -r requirements.txt (line 1)) (1.3.3)
# Requirement already satisfied: cycler==0.12.1 in c:\Users\Aleksandr Riabkov\Desktop\Itmo.py\ITMO.py\second_semester\LR5. Scikit-learn. Regression\venv\Lib\site-packages (from -r requirements.txt (line 2)) (0.12.1)
# Requirement already satisfied: fonttools==4.62.1 in c:\Users\Aleksandr Riabkov\Desktop\Itmo.py\ITMO.py\second_semester\LR5. Scikit-learn. Regression\venv\Lib\site-packages (from -r requirements.txt (line 3)) (4.62.1)
# Requirement already satisfied: kiwisolver==1.5.0 in c:\Users\Aleksandr Riabkov\Desktop\Itmo.py\ITMO.py\second_semester\LR5. Scikit-learn. Regression\venv\Lib\site-packages (from -r requirements.txt (line 4)) (1.5.0)
# Requirement already satisfied: matplotlib==3.10.8 in c:\Users\Aleksandr Riabkov\Desktop\Itmo.py\ITMO.py\second_semester\LR5. Scikit-learn. Regression\venv\Lib\site-packages (from -r requirements.txt (line 5)) (3.10.8)
# Requirement already satisfied: numpy==2.4.4 in c:\Users\Aleksandr Riabkov\Desktop\Itmo.py\ITMO.py\second_semester\LR5. Scikit-learn. Regression\venv\Lib\site-packages (from -r requirements.txt (line 6)) (2.4.4)
# Requirement already satisfied: packaging==26.0 in c:\Users\Aleksandr Riabkov\Desktop\Itmo.py\ITMO.py\second_semester\LR5. Scikit-learn. Regression\venv\Lib\site-packages (from -r requirements.txt (line 7)) (26.0)
# Requirement already satisfied: pandas==3.0.2 in c:\Users\Aleksandr Riabkov\Desktop\Itmo.py\ITMO.py\second_semester\LR5. Scikit-learn. Regression\venv\Lib\site-packages (from -r requirements.txt (line 8)) (3.0.2)
# Requirement already satisfied: pillow==12.2.0 in c:\Users\Aleksandr Riabkov\Desktop\Itmo.py\ITMO.py\second_semester\LR5. Scikit-learn. Regression\venv\Lib\site-packages (from -r requirements.txt (line 9)) (12.2.0)
# Requirement already satisfied: pyparsing==3.3.2 in c:\Users\Aleksandr Riabkov\Desktop\Itmo.py\ITMO.py\second_semester\LR5. Scikit-learn. Regression\venv\Lib\site-packages (from -r requirements.txt (line 10)) (3.3.2)
# Requirement already satisfied: python-dateutil==2.9.0.post0 in c:\Users\Aleksandr Riabkov\Desktop\Itmo.py\ITMO.py\second_semester\LR5. Scikit-learn. Regression\venv\Lib\site-packages (from -r requirements.txt (line 11)) (2.9.0.post0)
# Requirement already satisfied: seaborn==0.13.2 in c:\Users\Aleksandr Riabkov\Desktop\Itmo.py\ITMO.py\second_semester\LR5. Scikit-learn. Regression\venv\Lib\site-packages (from -r requirements.txt (line 12)) (0.13.2)
# Requirement already satisfied: six==1.17.0 in c:\Users\Aleksandr Riabkov\Desktop\Itmo.py\ITMO.py\second_semester\LR5. Scikit-learn. Regression\venv\Lib\site-packages (from -r requirements.txt (line 13)) (1.17.0)
# Requirement already satisfied: tzdata==2026.1 in c:\Users\Aleksandr Riabkov\Desktop\Itmo.py\ITMO.py\second_semester\LR5. Scikit-learn. Regression\venv\Lib\site-packages (from -r requirements.txt (line 14)) (2026.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Импорт всех модулей
import numpy as np 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt 
import scipy as sp

# %%
# Настройки
pd.set_option('display.max_columns', None)
sns.set_theme(style='whitegrid', palette='Set2')
plt.rcParams['figure.figsize'] = (10, 5)
plt.rcParams['axes.titlesize'] = 14
plt.rcParams['axes.labelsize'] = 12

# %% [markdown]
# ## EDA

# %%
# Импорт данных

df = pd.read_csv('data/titanic_dataset.csv')

df.head(5)
# df.tail(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ## Filling blanks

# %% [markdown]
# winsorisation:
#
# pandas - quantile
# scipy - winsorise
